# %%
import pandas
schools = pandas.read_csv("data/SAT_Results.csv", dtype=str)
schools.insert(2,'lat',0)
schools.insert(3,'lon',0)
schools.head()
# Out:
#       DBN                                    SCHOOL NAME  lat  lon  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    0    0
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    0    0
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL    0    0
# 3  01M458                      FORSYTH SATELLITE ACADEMY    0    0
# 4  01M509                        MARTA VALLE HIGH SCHOOL    0    0
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# ...

# %%
import geocoder
itp = geocoder.google(u"Interactive Telecommunications Program, New York")
test_school = geocoder.google(schools['SCHOOL NAME'][1])
print itp.latlng
print test_school.latlng
# Out:
# [40.7294245, -73.993707]
# [40.71226, -73.9838742]

# %%
coords = []
x=0
for name, row in schools.iterrows():
    try:
        school = geocoder.google(row['SCHOOL NAME'])
        lat, lon = school.latlng
        schools['lat'][x] = str(lat)
        schools['lon'][x] = str(lon)
        x+=1
        print lat, lon
    except:
        print 'fail', add
        continue
schools.to_csv('schools_latlon.csv', sep=',')
# Out:
# 40.7134455 -73.9860332
# 40.71226 -73.9838742
# 40.7293824 -73.982502
# 40.7221984 -73.9907155
# 40.7205149 -73.9856828
# 40.720534 -73.985986
# 40.7191667 -73.9797222
# 40.7221767 -73.9906357
# 40.7182547 -73.9760185
# 40.7382609 -73.9812096
# 40.7655356 -73.9931625
# 40.717321 -73.989323
# 40.7655356 -73.9931625
# 30.6133404 -87.1533875
# 40.7655356 -73.9931625
# 40.7655356 -73.9931625
# 40.717321 -73.989323
# 40.7169645 -73.9895323
# 40.743248 -74.002695
# 40.7054423 -74.0128882
# 40.7353879 -73.987228
# 40.7244683 -74.004946
# 40.7433678 -74.0025475
# 40.7639937 -73.9904866
# 40.7165187 -73.993222
# 40.7353237 -73.9870812
# 40.7679759 -73.9881796
# 40.7326759 -73.9825764
# 40.7615598 -73.9884908
# 40.7418485 -73.985909
# 40.7425709 -74.0023709
# 40.7390867 -73.9853658
# 40.7425709 -74.0023709
# 33.953061 -117.5687528
# 33.4945373 -112.3772714
# 40.7431223 -74.0025077
# 40.7325413 -73.9828421
# 40.7089611 -74.0124334
# 40.7464329 -73.9811232
# 40.7364053 -73.9957205
# ...
